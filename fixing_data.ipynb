# %%
# code to get to car data.csv
#data = pd.read_csv("jiji.csv",on_bad_lines='skip',encoding="ISO-8859–1")
#data.columns = ["img_link","Name","price","region","description","use","gearbox",'mileage']
#print(data.head(10))
#filepath = 'webscraping/car_data.xlsx'
#data.to_excel(filepath)

# %%
import pandas as pd

# %%
data = pd.read_excel("webscraping-data-store/car_data.xlsx")

# %%
#checking for null values in the data data
data.isna().sum()
# Out:
# Unnamed: 0      0
# img_link        0
# Name            0
# price           0
# region          0
# description     0
# use             0
# gearbox         0
# mileage        50
# dtype: int64

# %%
#filling null values
data.mileage.fillna("0",inplace=True)

# %%
#checking for duplicate data
duplicated_Data = data[data.duplicated(['img_link'])]
duplicated_Data
# Out:
#     Unnamed: 0                                           img_link  \
# 79          79  https://pictures-kenya.jijistatic.com/34575766...
#
#                                 Name          price               region  \
# 79  Mazda Axela SV Premium 2014 Blue  KSh 1,450,000   Nairobi, Lavington
#
#                                           description          use    gearbox  \
# 79  2014 model :: Hatchback ::1500cc :: Alloy whee...  Kenyan Used  Automatic
#
#     mileage
# 79  98000km

# %%
data.drop_duplicates(['img_link'],inplace=True)

# %%
type(data.price[0])
# Out:
# str

# %%
data["mileage"] = data["mileage"].map(lambda x :int(x.replace("km","")))
data.mileage
# Out:
# 0          0
# 1          0
# 2      85000
# 3      95000
# 4          0
#        ...
# 165    67000
# 166        0
# 167    25000
# 168        0
# 169        0
# Name: mileage, Length: 169, dtype: int64

# %%
data["price"] = data["price"].map(lambda x :int(x.replace("KSh","").replace(",","")))

# %%
type(data.mileage[0])
# Out:
# numpy.int64

# %%
data["town"] = data["region"].map(lambda x:x.split(",")[1:][0])
data["Region"] = data["region"].map(lambda x:x.split(",")[:1][0])

# %%
import re
pattern = "\d{4}"
data["Year_of_manufacture"] =data["Name"].map(lambda x:re.findall(pattern,x)[0])

# %%
pattern2 = "\d{4}cc"
pattern3 = "\d{4}CC"
pattern4 = "\d{4} CC"
#data["CC"] = data["description"].map(lambda x:getCC(x))
def getCC(data):
    if(re.findall(pattern3,data)):
        return re.findall(pattern3,data)[0]
    elif(re.findall(pattern2,data)):
        return re.findall(pattern2,data)[0]
    elif(re.findall(pattern4,data)):
        return re.findall(pattern4,data)[0] 
    else:
        return "Not specified"


data["CC"] = data["description"].map(lambda x:getCC(x))

# %%
data.head(22)
# Out:
#     Unnamed: 0                                           img_link  \
# 0            0  https://pictures-kenya.jijistatic.com/31819861...
# 1            1  https://pictures-kenya.jijistatic.com/28723044...
# 2            2  https://pictures-kenya.jijistatic.com/32300400...
# 3            3  https://pictures-kenya.jijistatic.com/34488388...
# 4            4  https://pictures-kenya.jijistatic.com/32841183...
# 5            5  https://pictures-kenya.jijistatic.com/30622829...
# 6            6  https://pictures-kenya.jijistatic.com/31721686...
# 7            7  https://pictures-kenya.jijistatic.com/19510810...
# 8            8  https://pictures-kenya.jijistatic.com/19517315...
# 9            9  https://pictures-kenya.jijistatic.com/27708003...
# 10          10  https://pictures-kenya.jijistatic.com/34773495...
# 11          11  https://pictures-kenya.jijistatic.com/32066627...
# 12          12  https://pictures-kenya.jijistatic.com/32600654...
# 14  Axela 2014cash 1.4new number kdc we accept cas...  Foreign Used
# 15  Clean mazda axela on sale.price ksh 1.5mcash,h...  Foreign Used
# 16                         Mazda axelahatchback1500cc  Foreign Used
# 17   Axela2014new number kddlow milagealloysnew tyres  Foreign Used
# 18  Mazda axela, saloon,1500cc,petrol,redwine colo...  Foreign Used
# 19                              Mazda axela20141490cc  Foreign Used
# 20  mazda axela sedan 2015 with full spec 1500cc p...  Foreign Used
# 21  Mazda axela20151490ccdark blue colour up head ...  Foreign Used
#
#       gearbox  mileage               town    Region Year_of_manufacture  \
# 0   Automatic        0              Runda   Nairobi                2014
# 1   Automatic        0            Donholm   Nairobi                2010
# 2      Manual    85000        Mombasa CBD   Mombasa                2015
# 3   Automatic    95000           Kasarani   Nairobi                2013
# 4   Automatic        0           Kasarani   Nairobi                2014
# 5   Automatic    95000        Mombasa CBD   Mombasa                2014
# 6   Automatic        0        Mombasa CBD   Mombasa                2014
# 7   Automatic    89653            Ganjoni   Mombasa                2014
# 8   Automatic    56324            Ganjoni   Mombasa                2014
# 9   Automatic    88000        Mombasa CBD   Mombasa                2014
# 10  Automatic        0   Kiambu / Kiambu     Kiambu                2014
# 11  Automatic        0   Kiambu / Kiambu     Kiambu                2014
# 12  Automatic    57000           Kilimani   Nairobi                2015
# 13  Automatic    49881            Ganjoni   Mombasa                2015
# 14  Automatic    56332            Ganjoni   Mombasa                2014
# 15  Automatic    63125              Mvita   Mombasa                2015
# 16  Automatic    68000        Mombasa CBD   Mombasa                2014
# 17  Automatic    60774        Mombasa CBD   Mombasa                2014
# 18  Automatic   136000        Mombasa CBD   Mombasa                2014
# 19  Automatic        0           Kilimani   Nairobi                2014
# 20  Automatic    94000           Kilimani   Nairobi                2015
# 21  Automatic        0           Kilimani   Nairobi                2015
#
#                CC
# 0          1500cc
# 1   Not specified
# 2   Not specified
# 3          1500cc
# 4          2200CC
# 5   Not specified
# 6   Not specified
# 7   Not specified
# 8   Not specified
# 9   Not specified
# 10  Not specified
# 11         2000cc
# 12  Not specified
# 13  Not specified
# 14  Not specified
# 15  Not specified
# 16         1500cc
# 17  Not specified
# 18         1500cc
# 19         1490cc
# 20         1500cc
# 21         1490cc

# %%
data.Year_of_manufacture
# Out:
# 0      2014
# 1      2010
# 2      2015
# 3      2013
# 4      2014
#        ...
# 165    2014
# 166    2013
# 167    2014
# 168    2014
# 169    2013
# Name: Year_of_manufacture, Length: 169, dtype: object

# %%
data.drop(columns=["Unnamed: 0"],inplace =True)

# %%
data.to_csv("webscraping-data-store/clean_data.csv")

# %%
data.CC
# Out:
# 0             1500cc
# 1      Not specified
# 2      Not specified
# 3             1500cc
# 4             2200CC
#            ...
# 165    Not specified
# 166           1500cc
# 167    Not specified
# 168          1500 CC
# 169           1500cc
# Name: CC, Length: 169, dtype: object

# %%
data.columns
# Out:
# Index(['img_link', 'Name', 'price', 'region', 'description', 'use', 'gearbox',
#        'mileage', 'town', 'Region', 'Year_of_manufacture', 'CC'],
#       dtype='object')

# %%
data.Region.unique()
# Out:
# array([' Nairobi', ' Mombasa', ' Kiambu'], dtype=object)
